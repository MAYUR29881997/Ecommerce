# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel (r"C:\Users\my\OneDrive\Desktop\Ecommerce project\ecommerce_clean_final_data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4804 entries, 0 to 4803
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           4804 non-null   int64
#  1   Age                  4804 non-null   int64
#  2   Gender               4804 non-null   object
#  3   Location             4804 non-null   object
#  4   OrderID              4804 non-null   int64
#  5   ProductID            4804 non-null   int64
#  6   Category             4804 non-null   object
#  7   Price                4804 non-null   float64
#  8   Quantity             4804 non-null   int64
#  9   Discount(%)          4804 non-null   int64
#  10  PaymentMethod        4804 non-null   object
#  11  PurchaseDate         4804 non-null   datetime64[ns]
#  12  Rating               4804 non-null   int64
#  13  ShipmentTime(days)   4804 non-null   float64
#  14  LateDelivery         4804 non-null   bool
#  15  CourierPartner       4804 non-null   object
#  16  LastLogin(days)      4804 non-null   int64
#  17  PurchaseFrequency    4804 non-null   object
#  18  CartAbandonmentRate  4804 non-null   float64
#  19  ClicksPerSession     4804 non-null   float64
#  20  Revenue              4804 non-null   float64
#  21  Returned             4804 non-null   bool
#  22  ReturnReason         4804 non-null   object
#  23  ChurnRiskScore       4804 non-null   float64
#  24  Price_Level          4804 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(6), int64(8), object(8)
# memory usage: 872.7+ KB

# %%
df.mean(numeric_only=True)
# Out:
# CustomerID               5476.097419
# Age                        43.100749
# OrderID                548739.856994
# ProductID               55316.955454
# Price                     100.927082
# Quantity                    2.509784
# Discount(%)                10.113447
# Rating                      3.005412
# ShipmentTime(days)          2.975489
# LateDelivery                0.192340
# LastLogin(days)            29.487094
# CartAbandonmentRate         0.500298
# ClicksPerSession            4.973772
# Revenue                   225.270238
# Returned                    0.106578
# ChurnRiskScore              0.501380
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# CustomerID               5493.00
# Age                        43.00
# OrderID                548830.50
# ProductID               55319.50
# Price                     100.38
# Quantity                    2.00
# Discount(%)                10.00
# Rating                      3.00
# ShipmentTime(days)          3.00
# LateDelivery                0.00
# LastLogin(days)            30.00
# CartAbandonmentRate         0.51
# ClicksPerSession            5.00
# Revenue                   192.76
# Returned                    0.00
# ChurnRiskScore              0.51
# dtype: float64

# %%
df.mode()
# Out:
#    CustomerID   Age  Gender Location  OrderID  ProductID Category  Price  \
# 0      5780.0  43.0  Female    Rural   301157    11634.0   Beauty  236.5
# 1         NaN   NaN    Male      NaN   444417    25316.0      NaN    NaN
# 2         NaN   NaN     NaN      NaN   448492    52861.0      NaN    NaN
# 3         NaN   NaN     NaN      NaN   457659    76500.0      NaN    NaN
# 4         NaN   NaN     NaN      NaN   600642        NaN      NaN    NaN
# 5         NaN   NaN     NaN      NaN   741191        NaN      NaN    NaN
# 6         NaN   NaN     NaN      NaN   778627        NaN      NaN    NaN
# 7         NaN   NaN     NaN      NaN   884118        NaN      NaN    NaN
# 8         NaN   NaN     NaN      NaN   911399        NaN      NaN    NaN
# 9         NaN   NaN     NaN      NaN   916700        NaN      NaN    NaN
#
#    Quantity  Discount(%)  ... CourierPartner LastLogin(days)  \
# 0       2.0         15.0  ...            DHL            19.0
# 1       NaN          NaN  ...            NaN             NaN
# 2       NaN          NaN  ...            NaN             NaN
# 3       NaN          NaN  ...            NaN             NaN
# 4       NaN          NaN  ...            NaN             NaN
# 5       NaN          NaN  ...            NaN             NaN
# 6       NaN          NaN  ...            NaN             NaN
# 7       NaN          NaN  ...            NaN             NaN
# 8       NaN          NaN  ...            NaN             NaN
# 9       NaN          NaN  ...            NaN             NaN
#
#    PurchaseFrequency  CartAbandonmentRate ClicksPerSession    Revenue  \
# 0             Medium                 0.07              4.0  647.48125
# 1                NaN                 0.77              NaN        NaN
# 2                NaN                  NaN              NaN        NaN
# 3                NaN                  NaN              NaN        NaN
# 4                NaN                  NaN              NaN        NaN
# 5                NaN                  NaN              NaN        NaN
# 6                NaN                  NaN              NaN        NaN
# 7                NaN                  NaN              NaN        NaN
# 8                NaN                  NaN              NaN        NaN
# 9                NaN                  NaN              NaN        NaN
#
#    Returned ReturnReason  ChurnRiskScore  Price_Level
# 0     False   Wrong Item            0.79       Medium
# 1       NaN          NaN            0.84          NaN
# 2       NaN          NaN             NaN          NaN
# 3       NaN          NaN             NaN          NaN
# 4       NaN          NaN             NaN          NaN
# 5       NaN          NaN             NaN          NaN
# 6       NaN          NaN             NaN          NaN
# 7       NaN          NaN             NaN          NaN
# 8       NaN          NaN             NaN          NaN
# 9       NaN          NaN             NaN          NaN
#
# [10 rows x 25 columns]

# %%
df.var(numeric_only=True)
# Out:
# CustomerID             6.650014e+06
# Age                    2.108431e+02
# OrderID                6.759228e+10
# ProductID              6.866021e+08
# Price                  2.524465e+03
# Quantity               1.237256e+00
# Discount(%)            4.940936e+01
# Rating                 1.919604e+00
# ShipmentTime(days)     2.074179e+00
# LateDelivery           1.553775e-01
# LastLogin(days)        2.976007e+02
# CartAbandonmentRate    8.309562e-02
# ClicksPerSession       4.713449e+00
# Revenue                2.452056e+04
# Returned               9.523884e-02
# ChurnRiskScore         8.473853e-02
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# CustomerID               2578.762086
# Age                        14.520436
# OrderID                259985.143868
# ProductID               26203.094000
# Price                      50.244056
# Quantity                    1.112320
# Discount(%)                 7.029179
# Rating                      1.385498
# ShipmentTime(days)          1.440201
# LateDelivery                0.394180
# LastLogin(days)            17.251107
# CartAbandonmentRate         0.288263
# ClicksPerSession            2.171048
# Revenue                   156.590426
# Returned                    0.308608
# ChurnRiskScore              0.291099
# dtype: float64

# %%
range1=df.select_dtypes(include=['int','float']).columns

# %%
for i in range1:
    r1=df[range1].max()-df[range1].min()
print(r1)
# Out:
# CustomerID               8995.00
# Age                        51.00
# OrderID                899847.00
# ProductID               89982.00
# Price                     271.76
# Quantity                    3.00
# Discount(%)                20.00
# Rating                      4.00
# ShipmentTime(days)          7.60
# LastLogin(days)            59.00
# CartAbandonmentRate         1.00
# ClicksPerSession           10.50
# Revenue                   867.63
# ChurnRiskScore              1.00
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# CustomerID             0.000617
# Age                    0.049218
# OrderID                0.014247
# ProductID             -0.010543
# Price                  0.058704
# Quantity               0.001261
# Discount(%)           -0.017332
# Rating                 0.006759
# ShipmentTime(days)     0.012381
# LateDelivery           1.561666
# LastLogin(days)        0.004114
# CartAbandonmentRate   -0.026621
# ClicksPerSession       0.334371
# Revenue                0.759575
# Returned               2.550719
# ChurnRiskScore        -0.023664
# dtype: float64

# %%
sns.histplot(df['Price'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.countplot(x=df['Quantity'])
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['Discount(%)'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['Revenue'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['ShipmentTime(days)'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.countplot(x=df['PurchaseFrequency'])
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['ClicksPerSession'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['ChurnRiskScore'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.countplot(x=df['Rating'])
plt.title('skewness')
# Out:
# Text(0.5, 1.0, 'skewness')

# %%
df.kurt(numeric_only=True)
# Out:
# CustomerID            -1.197438
# Age                   -1.079817
# OrderID               -1.181375
# ProductID             -1.240964
# Price                 -0.140338
# Quantity              -1.347091
# Discount(%)           -1.293488
# Rating                -1.217092
# ShipmentTime(days)    -0.041666
# LateDelivery           0.438984
# LastLogin(days)       -1.171595
# CartAbandonmentRate   -1.207411
# ClicksPerSession      -0.208788
# Revenue                0.064729
# Returned               4.508044
# ChurnRiskScore        -1.229790
# dtype: float64

# %%
sns.histplot(df['Price'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.countplot(x=df['Quantity'])
plt.title('kurtosis')
# Out:
# Text(0.5, 1.0, 'kurtosis')

# %%
sns.histplot(df['Discount(%)'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.histplot(df['Revenue'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.histplot(df['ShipmentTime(days)'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.countplot(x=df['PurchaseFrequency'])
plt.title('Kurtosis')
plt.show()

# %%
sns.histplot(df['ClicksPerSession'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.histplot(df['ChurnRiskScore'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.countplot(x=df['Rating'])
plt.title('kurtosis')
plt.show()
