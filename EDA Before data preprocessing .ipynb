# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel(r"C:\Users\my\OneDrive\Desktop\Ecommerce project\5k+ecommerce_dataset (1).xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           5200 non-null   int64
#  1   Age                  4943 non-null   float64
#  2   Gender               5200 non-null   object
#  3   Location             5200 non-null   object
#  4   OrderID              5200 non-null   int64
#  5   ProductID            5200 non-null   int64
#  6   Category             5200 non-null   object
#  7   Price                5200 non-null   float64
#  8   Quantity             5200 non-null   int64
#  9   Discount(%)          5200 non-null   int64
#  10  PaymentMethod        5200 non-null   object
#  11  PurchaseDate         5200 non-null   datetime64[ns]
#  12  Rating               4937 non-null   float64
#  13  ShipmentTime(days)   4935 non-null   float64
#  14  LateDelivery         5200 non-null   bool
# ...

# %%
df.mean(numeric_only=True)
# Out:
# CustomerID               5487.172308
# Age                        43.112078
# OrderID                549357.479038
# ProductID               55316.820385
# Price                     101.515400
# Quantity                    2.498654
# Discount(%)                10.122115
# Rating                      3.004456
# ShipmentTime(days)          2.990983
# LateDelivery                0.191538
# LastLogin(days)            29.468077
# CartAbandonmentRate         0.501952
# ClicksPerSession            4.981346
# Revenue                   224.564935
# Returned                    0.105000
# ChurnRiskScore              0.500429
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# CustomerID               5498.000
# Age                        43.000
# OrderID                550775.000
# ProductID               55396.500
# Price                      99.745
# Quantity                    2.000
# Discount(%)                10.000
# Rating                      3.000
# ShipmentTime(days)          3.000
# LateDelivery                0.000
# LastLogin(days)            30.000
# CartAbandonmentRate         0.510
# ClicksPerSession            5.000
# Revenue                   189.890
# Returned                    0.000
# ChurnRiskScore              0.500
# dtype: float64

# %%
df.mode()
# Out:
#      CustomerID   Age Gender Location   OrderID  ProductID Category  Price  \
# 0        1956.0  56.0   Male    Rural  973523.0    11316.0   Beauty  59.06
# 1        5780.0   NaN    NaN      NaN       NaN    11634.0      NaN    NaN
# 2           NaN   NaN    NaN      NaN       NaN    19849.0      NaN    NaN
# 3           NaN   NaN    NaN      NaN       NaN    25316.0      NaN    NaN
# 4           NaN   NaN    NaN      NaN       NaN    25740.0      NaN    NaN
# ..          ...   ...    ...      ...       ...        ...      ...    ...
# 195         NaN   NaN    NaN      NaN       NaN        NaN      NaN    NaN
# 196         NaN   NaN    NaN      NaN       NaN        NaN      NaN    NaN
# 197         NaN   NaN    NaN      NaN       NaN        NaN      NaN    NaN
# 198         NaN   NaN    NaN      NaN       NaN        NaN      NaN    NaN
# 199         NaN   NaN    NaN      NaN       NaN        NaN      NaN    NaN
#
# ...

# %%
df.var(numeric_only=True)
# Out:
# CustomerID             6.625657e+06
# Age                    2.224071e+02
# OrderID                6.823121e+10
# ProductID              6.869009e+08
# Price                  3.776342e+03
# Quantity               1.244468e+00
# Discount(%)            4.915319e+01
# Rating                 2.000791e+00
# ShipmentTime(days)     2.623293e+00
# LateDelivery           1.548813e-01
# LastLogin(days)        2.965152e+02
# CartAbandonmentRate    8.275986e-02
# ClicksPerSession       4.916174e+00
# Revenue                2.584593e+04
# Returned               9.399308e-02
# ChurnRiskScore         8.424346e-02
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# CustomerID               2574.035095
# Age                        14.913320
# OrderID                261211.036114
# ProductID               26208.794387
# Price                      61.451952
# Quantity                    1.115557
# Discount(%)                 7.010934
# Rating                      1.414493
# ShipmentTime(days)          1.619658
# LateDelivery                0.393550
# LastLogin(days)            17.219618
# CartAbandonmentRate         0.287680
# ClicksPerSession            2.217245
# Revenue                   160.766707
# Returned                    0.306583
# ChurnRiskScore              0.290247
# dtype: float64

# %%
range1=df.select_dtypes(include=['int','float']).columns

# %%
for i in range1:
    r1=df[range1].max()-df[range1].min()
print(r1)
# Out:
# CustomerID               8995.00
# Age                        51.00
# OrderID                899847.00
# ProductID               89982.00
# Price                    1410.58
# Quantity                    3.00
# Discount(%)                20.00
# Rating                      4.00
# ShipmentTime(days)         30.70
# LastLogin(days)            59.00
# CartAbandonmentRate         1.00
# ClicksPerSession           14.00
# Revenue                  1348.36
# ChurnRiskScore              1.00
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# CustomerID            -0.006405
# Age                    0.047058
# OrderID                0.007716
# ProductID             -0.016311
# Price                  5.286468
# Quantity               0.019595
# Discount(%)           -0.013682
# Rating                 0.010597
# ShipmentTime(days)     1.836688
# LateDelivery           1.568190
# LastLogin(days)        0.000999
# CartAbandonmentRate   -0.031060
# ClicksPerSession       0.454929
# Revenue                0.957292
# Returned               2.577782
# ChurnRiskScore        -0.016642
# dtype: float64

# %%
sns.histplot(df['Price'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.countplot(x=df['Quantity'])
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['Discount(%)'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['Revenue'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['ShipmentTime(days)'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.countplot(x=df['PurchaseFrequency'])
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['ClicksPerSession'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['ChurnRiskScore'],kde=True)
plt.title('skewness')
plt.show()

# %%
sns.countplot(x=df['Rating'])
plt.title('skewness')
# Out:
# Text(0.5, 1.0, 'skewness')

# %%
df.kurt(numeric_only=True)
# Out:
# CustomerID             -1.194179
# Age                    -1.180620
# OrderID                -1.195005
# ProductID              -1.240489
# Price                  89.259787
# Quantity               -1.354130
# Discount(%)            -1.285137
# Rating                 -1.294647
# ShipmentTime(days)     23.181282
# LateDelivery            0.459396
# LastLogin(days)        -1.165951
# CartAbandonmentRate    -1.206344
# ClicksPerSession        0.239376
# Revenue                 0.938310
# Returned                4.646748
# ChurnRiskScore         -1.223714
# dtype: float64

# %%
sns.histplot(df['Price'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.countplot(x=df['Quantity'])
plt.title('skewness')
plt.show()

# %%
sns.histplot(df['Discount(%)'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.histplot(df['Revenue'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.histplot(df['ShipmentTime(days)'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.countplot(x=df['PurchaseFrequency'])
plt.title('Kurtosis')
plt.show()

# %%
sns.histplot(df['ClicksPerSession'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.histplot(df['ChurnRiskScore'],kde=True)
plt.title('kurtosis')
plt.show()

# %%
sns.countplot(x=df['Rating'])
plt.title('kurtosis')
# Out:
# Text(0.5, 1.0, 'kurtosis')
